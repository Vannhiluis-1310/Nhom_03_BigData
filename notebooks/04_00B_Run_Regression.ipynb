# %% [markdown]
# # 04_00B Run Regression Notebooks
# Chay 04_06 -> 04_08.

# %%
from pathlib import Path
import subprocess, sys
import pandas as pd
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
NOTEBOOK_DIR = PROJECT_ROOT / 'notebooks'
STOP_ON_ERROR = True
run_list = [
 '04_06_Regression_LinearRegression.ipynb',
 '04_07_Regression_DecisionTreeRegressor.ipynb',
 '04_08_Regression_RandomForestRegressor.ipynb',
]
results = []
for nb in run_list:
    src = NOTEBOOK_DIR / nb
    cmd = [sys.executable, '-m', 'jupyter', 'nbconvert', '--to', 'notebook', '--execute', '--inplace', '--ExecutePreprocessor.kernel_name=python3', str(src)]
    proc = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)
    if proc.returncode == 0:
        results.append((nb, 'ok', 'executed'))
        print('[OK]', nb)
    else:
        err = (proc.stderr or proc.stdout or '')[:1500]
        results.append((nb, 'failed', err))
        print('[FAILED]', nb)
        if STOP_ON_ERROR:
            break
summary = pd.DataFrame(results, columns=['notebook','status','message'])
print(summary.to_string(index=False))
out = PROJECT_ROOT / 'reports' / 'run_regression_summary.csv'
out.parent.mkdir(parents=True, exist_ok=True)
summary.to_csv(out, index=False)
print('Saved:', out)
# Out:
# [OK] 04_06_Regression_LinearRegression.ipynb
# [OK] 04_07_Regression_DecisionTreeRegressor.ipynb
# [OK] 04_08_Regression_RandomForestRegressor.ipynb
#                                     notebook status  message
#      04_06_Regression_LinearRegression.ipynb     ok executed
# 04_07_Regression_DecisionTreeRegressor.ipynb     ok executed
# 04_08_Regression_RandomForestRegressor.ipynb     ok executed
# Saved: C:\Users\vanhi\Desktop\HCMUTE_TMDT\HKII_Nam_3\BigData\Nhom03_PySpark_ProjectCuoiKy\reports\run_regression_summary.csv
